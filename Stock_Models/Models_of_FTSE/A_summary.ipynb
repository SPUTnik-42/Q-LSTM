# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
qlstm_loss = np.loadtxt('./SavedModels/Stock/FTSE/loss/qlstm.txt')
qgru_loss = np.loadtxt('./SavedModels/Stock/FTSE/loss/qgru.txt')
qlstm_attn_loss = np.loadtxt('./SavedModels/Stock/FTSE/loss/qlstm_attn.txt')
stacked_qlstm_loss = np.loadtxt('./SavedModels/Stock/FTSE/loss/stacked_qlstm.txt')
stacked_qgru_loss = np.loadtxt('./SavedModels/Stock/FTSE/loss/stacked_qgru.txt')
arima_qlstm_loss = np.loadtxt('./SavedModels/Stock/FTSE/loss/arima_qlstm.txt')
qblstm_loss = np.loadtxt('./SavedModels/Stock/FTSE/loss/qblstm.txt')

lstm_loss = np.loadtxt('./SavedModels/Stock/FTSE/loss/clstm.txt')
gru_loss = np.loadtxt('./SavedModels/Stock/FTSE/loss/cgru.txt')
lstm_attn_loss = np.loadtxt('./SavedModels/Stock/FTSE/loss/clstm_attn.txt')
stacked_lstm_loss = np.loadtxt('./SavedModels/Stock/FTSE/loss/stacked_clstm.txt')
stacked_gru_loss = np.loadtxt('./SavedModels/Stock/FTSE/loss/stacked_cgru.txt')
arima_lstm_loss = np.loadtxt('./SavedModels/Stock/FTSE/loss/arima_lstm.txt')
blstm_loss = np.loadtxt('./SavedModels/Stock/FTSE/loss/cblstm.txt')

# %%
y_train = np.loadtxt('./SavedModels/Stock/FTSE/y_train_true.txt')
y_test = np.loadtxt('./SavedModels/Stock/FTSE/y_test_true.txt')

# %%
qlstm_train = np.loadtxt('./SavedModels/Stock/FTSE/train/qlstm.txt')
qgru_train = np.loadtxt('./SavedModels/Stock/FTSE/train/qgru.txt')
qlstm_attn_train = np.loadtxt('./SavedModels/Stock/FTSE/train/qlstm_attn.txt')
stacked_qlstm_train = np.loadtxt('./SavedModels/Stock/FTSE/train/stacked_qlstm.txt')
stacked_qgru_train = np.loadtxt('./SavedModels/Stock/FTSE/train/stacked_qgru.txt')
arima_qlstm_train = np.loadtxt('./SavedModels/Stock/FTSE/train/arima_qlstm.txt')
qblstm_train = np.loadtxt('./SavedModels/Stock/FTSE/train/qblstm.txt')

lstm_train = np.loadtxt('./SavedModels/Stock/FTSE/train/clstm.txt')
gru_train = np.loadtxt('./SavedModels/Stock/FTSE/train/cgru.txt')
lstm_attn_train = np.loadtxt('./SavedModels/Stock/FTSE/train/clstm_attn.txt')
stacked_lstm_train = np.loadtxt('./SavedModels/Stock/FTSE/train/stacked_clstm.txt')
stacked_gru_train = np.loadtxt('./SavedModels/Stock/FTSE/train/stacked_cgru.txt')
arima_lstm_train= np.loadtxt('./SavedModels/Stock/FTSE/train/arima_lstm.txt')
blstm_train = np.loadtxt('./SavedModels/Stock/FTSE/train/cblstm.txt')

# %%
qlstm_test = np.loadtxt('./SavedModels/Stock/FTSE/test/qlstm.txt')
qgru_test = np.loadtxt('./SavedModels/Stock/FTSE/test/qgru.txt')
qlstm_attn_test= np.loadtxt('./SavedModels/Stock/FTSE/test/qlstm_attn.txt')
stacked_qlstm_test = np.loadtxt('./SavedModels/Stock/FTSE/test/stacked_qlstm.txt')
stacked_qgru_test = np.loadtxt('./SavedModels/Stock/FTSE/test/stacked_qgru.txt')
arima_qlstm_test = np.loadtxt('./SavedModels/Stock/FTSE/test/arima_qlstm.txt')
qblstm_test = np.loadtxt('./SavedModels/Stock/FTSE/test/qblstm.txt')

lstm_test = np.loadtxt('./SavedModels/Stock/FTSE/test/clstm.txt')
gru_test = np.loadtxt('./SavedModels/Stock/FTSE/test/cgru.txt')
lstm_attn_test = np.loadtxt('./SavedModels/Stock/FTSE/test/clstm_attn.txt')
stacked_lstm_test = np.loadtxt('./SavedModels/Stock/FTSE/test/stacked_clstm.txt')
stacked_gru_test = np.loadtxt('./SavedModels/Stock/FTSE/test/stacked_cgru.txt')
arima_lstm_test= np.loadtxt('./SavedModels/Stock/FTSE/test/arima_lstm.txt')
blstm_test = np.loadtxt('./SavedModels/Stock/FTSE/test/cblstm.txt')

# %%
fig, axs = plt.subplots(2,3, figsize=(20, 8))

axs[0, 0].plot(qlstm_loss, label='Quantum LSTM')
axs[0, 0].plot(lstm_loss, label= 'Classical LSTM')
axs[0, 0].legend()
axs[0, 0].set_title('Quantum LSTM Vs Classical LSTM Loss')

axs[0, 1].plot(qgru_loss, label='Quantum GRU')
axs[0, 1].plot(gru_loss, label='Classical GRU')
axs[0, 1].legend()
axs[0, 1].set_title('Quantum GRU Vs Classical GRU Loss')

axs[0, 2].plot(qblstm_loss, label='Quantum BiLSTM')
axs[0, 2].plot(blstm_loss, label='Classical BiLSTM')
axs[0, 2].legend()
axs[0, 2].set_title('Quantum BiLSTM Vs Classical BiLSTM Loss')

axs[1, 0].plot(qlstm_attn_loss,label='Quantum DA-LSTM')
axs[1, 0].plot(lstm_attn_loss,label='Classical DA-LSTM')
axs[1, 0].legend()
axs[1, 0].set_title('Quantum DA-LSTM Vs Classical DA-LSTM Loss')

axs[1, 1].plot(stacked_qlstm_loss,label='Quantum stacked LSTM' )
axs[1, 1].plot(stacked_lstm_loss,label='Classical stacked LSTM')
axs[1, 1].legend()
axs[1, 1].set_title('Quantum stacked LSTM Vs Classical stacked LSTM Loss')

axs[1, 2].plot(stacked_qgru_loss,label='Quantum stacked GRU')
axs[1, 2].plot(stacked_gru_loss,label='Classical stacked GRU')
axs[1, 2].legend()
axs[1, 2].set_title('Quantum stacked GRU Vs Classical stacked GRU Loss')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2,3, figsize=(20, 8))

axs[0, 0].plot(qlstm_test, label='Quantum LSTM', color='red', alpha=0.7)
axs[0, 0].plot(lstm_test, label= 'Classical LSTM', alpha=0.4)
axs[0, 0].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[0, 0].legend()
axs[0, 0].set_title('Quantum LSTM Vs Classical LSTM testing')

axs[0, 1].plot(qgru_test, label='Quantum GRU', color='red', alpha=0.7)
axs[0, 1].plot(gru_test, label='Classical GRU', alpha=0.4)
axs[0, 1].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[0, 1].legend()
axs[0, 1].set_title('Quantum GRU Vs Classical GRU testing')

axs[0, 2].plot(qblstm_test, label='Quantum BiLSTM', color='red', alpha=0.7)
axs[0, 2].plot(blstm_test, label='Classical BiLSTM', alpha=0.4)
axs[0, 2].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[0, 2].legend()
axs[0, 2].set_title('Quantum BiLSTM Vs Classical BiLSTM testing')

axs[1, 0].plot(qlstm_attn_test,label='Quantum DA-LSTM', color='red', alpha=0.7)
axs[1, 0].plot(lstm_attn_test,label='Classical DA-LSTM', alpha=0.4)
axs[1, 0].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[1, 0].legend()
axs[1, 0].set_title('Quantum DA-LSTM Vs Classical DA-LSTM testing')

axs[1, 1].plot(stacked_qlstm_test,label='Quantum stacked LSTM' , color='red', alpha=0.7)
axs[1, 1].plot(stacked_lstm_test,label='Classical stacked LSTM', alpha=0.4)
axs[1, 1].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[1, 1].legend()
axs[1, 1].set_title('Quantum stacked LSTM Vs Classical stacked LSTM testing')

axs[1, 2].plot(stacked_qgru_test,label='Quantum stacked GRU', color='red', alpha=0.7)
axs[1, 2].plot(stacked_gru_test,label='Classical stacked GRU', alpha=0.4)
axs[1, 2].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[1, 2].legend()
axs[1, 2].set_title('Quantum stacked GRU Vs Classical stacked GRU testing')

plt.tight_layout()
plt.show()

# %%
plt.plot(arima_qlstm_loss, label='ARIMA QLSTM')
plt.plot(arima_lstm_loss, label='ARIMA LSTM')
plt.legend()
plt.title('Quantum ARIMA QLSTM Vs Classical ARIMA LSTM Loss')
plt.show()

# %%
plt.plot(arima_qlstm_test, label='ARIMA QLSTM')
plt.plot(arima_lstm_test, label='ARIMA LSTM')
plt.legend()
plt.title('Quantum ARIMA QLSTM Vs Classical ARIMA LSTM testing')
plt.show()

# %%
X = ['LSTM', 'BiLSTM', 'GRU', 'DA-LSTM','Stacked LSTM', 'Stacked GRU', 'ARIMA-LSTM']
rmse_q = [63.25069614793417,65.03358453865242,61.80668932185422,30.288380424935674,62.8897631391977,63.22874851676668,56.73345986415789]
rmse_c = [47.50621283280725,49.40192325959232,37.74576720027077,17.066874731189998,60.021278818094714,50.51782975440088,59.92915692110727]

X_axis = np.arange(len(X)) 
plt.figure(figsize=(20,8))  
plt.bar(X_axis - 0.2, rmse_q, 0.4, label = 'Quantum RMSE') 
plt.bar(X_axis + 0.2, rmse_c, 0.4, label = 'Classical RMSE') 

plt.xticks(X_axis, X) 
plt.title("RMSE of Quantum and Classical LSTM Variants") 
plt.legend() 
plt.show()

# %%
import pandas as pd
rmse_models_NY = pd.DataFrame({'Model_Name': X, 'Quanutum RMSE': rmse_q, 'Classical RMSE': rmse_c})
rmse_models_NY
# Out:
#      Model_Name  Quanutum RMSE  Classical RMSE
# 0          LSTM      63.250696       47.506213
# 1        BiLSTM      65.033585       49.401923
# 2           GRU      61.806689       37.745767
# 3       DA-LSTM      30.288380       17.066875
# 4  Stacked LSTM      62.889763       60.021279
# 5   Stacked GRU      63.228749       50.517830
# 6    ARIMA-LSTM      56.733460       59.929157
