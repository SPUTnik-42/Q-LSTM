# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
qlstm_loss = np.loadtxt('./SavedModels/Weather/London/loss/qlstm.txt')
qgru_loss = np.loadtxt('./SavedModels/Weather/London/loss/qgru.txt')
qlstm_attn_loss = np.loadtxt('./SavedModels/Weather/London/loss/qlstm_attn.txt')
stacked_qlstm_loss = np.loadtxt('./SavedModels/Weather/London/loss/stacked_qlstm.txt')
stacked_qgru_loss = np.loadtxt('./SavedModels/Weather/London/loss/stacked_qgru.txt')
arima_qlstm_loss = np.loadtxt('./SavedModels/Weather/London/loss/arima_qlstm.txt')
qblstm_loss = np.loadtxt('./SavedModels/Weather/London/loss/qblstm.txt')

lstm_loss = np.loadtxt('./SavedModels/Weather/London/loss/clstm.txt')
gru_loss = np.loadtxt('./SavedModels/Weather/London/loss/cgru.txt')
lstm_attn_loss = np.loadtxt('./SavedModels/Weather/London/loss/clstm_attn.txt')
stacked_lstm_loss = np.loadtxt('./SavedModels/Weather/London/loss/stacked_clstm.txt')
stacked_gru_loss = np.loadtxt('./SavedModels/Weather/London/loss/stacked_cgru.txt')
arima_lstm_loss = np.loadtxt('./SavedModels/Weather/London/loss/arima_lstm.txt')
blstm_loss = np.loadtxt('./SavedModels/Weather/London/loss/cblstm.txt')

# %%
y_train = np.loadtxt('./SavedModels/Weather/London/y_train_true.txt')
y_test = np.loadtxt('./SavedModels/Weather/London/y_test_true.txt')

# %%
qlstm_train = np.loadtxt('./SavedModels/Weather/London/train/qlstm.txt')
qgru_train = np.loadtxt('./SavedModels/Weather/London/train/qgru.txt')
qlstm_attn_train = np.loadtxt('./SavedModels/Weather/London/train/qlstm_attn.txt')
stacked_qlstm_train = np.loadtxt('./SavedModels/Weather/London/train/stacked_qlstm.txt')
stacked_qgru_train = np.loadtxt('./SavedModels/Weather/London/train/stacked_qgru.txt')
arima_qlstm_train = np.loadtxt('./SavedModels/Weather/London/train/arima_qlstm.txt')
qblstm_train = np.loadtxt('./SavedModels/Weather/London/train/qblstm.txt')

lstm_train = np.loadtxt('./SavedModels/Weather/London/train/clstm.txt')
gru_train = np.loadtxt('./SavedModels/Weather/London/train/cgru.txt')
lstm_attn_train = np.loadtxt('./SavedModels/Weather/London/train/clstm_attn.txt')
stacked_lstm_train = np.loadtxt('./SavedModels/Weather/London/train/stacked_clstm.txt')
stacked_gru_train = np.loadtxt('./SavedModels/Weather/London/train/stacked_cgru.txt')
arima_lstm_train= np.loadtxt('./SavedModels/Weather/London/train/arima_lstm.txt')
blstm_train = np.loadtxt('./SavedModels/Weather/London/train/cblstm.txt')

# %%
qlstm_test = np.loadtxt('./SavedModels/Weather/London/test/qlstm.txt')
qgru_test = np.loadtxt('./SavedModels/Weather/London/test/qgru.txt')
qlstm_attn_test= np.loadtxt('./SavedModels/Weather/London/test/qlstm_attn.txt')
stacked_qlstm_test = np.loadtxt('./SavedModels/Weather/London/test/stacked_qlstm.txt')
stacked_qgru_test = np.loadtxt('./SavedModels/Weather/London/test/stacked_qgru.txt')
arima_qlstm_test = np.loadtxt('./SavedModels/Weather/London/test/arima_qlstm.txt')
qblstm_test = np.loadtxt('./SavedModels/Weather/London/test/qblstm.txt')

lstm_test = np.loadtxt('./SavedModels/Weather/London/test/clstm.txt')
gru_test = np.loadtxt('./SavedModels/Weather/London/test/cgru.txt')
lstm_attn_test = np.loadtxt('./SavedModels/Weather/London/test/clstm_attn.txt')
stacked_lstm_test = np.loadtxt('./SavedModels/Weather/London/test/stacked_clstm.txt')
stacked_gru_test = np.loadtxt('./SavedModels/Weather/London/test/stacked_cgru.txt')
arima_lstm_test= np.loadtxt('./SavedModels/Weather/London/test/arima_lstm.txt')
blstm_test = np.loadtxt('./SavedModels/Weather/London/test/cblstm.txt')

# %%
fig, axs = plt.subplots(2,3, figsize=(20, 8))

axs[0, 0].plot(qlstm_loss, label='Quantum LSTM')
axs[0, 0].plot(lstm_loss, label= 'Classical LSTM')
axs[0, 0].legend()
axs[0, 0].set_title('Quantum LSTM Vs Classical LSTM Loss')

axs[0, 1].plot(qgru_loss, label='Quantum GRU')
axs[0, 1].plot(gru_loss, label='Classical GRU')
axs[0, 1].legend()
axs[0, 1].set_title('Quantum GRU Vs Classical GRU Loss')

axs[0, 2].plot(qblstm_loss, label='Quantum BiLSTM')
axs[0, 2].plot(blstm_loss, label='Classical BiLSTM')
axs[0, 2].legend()
axs[0, 2].set_title('Quantum BiLSTM Vs Classical BiLSTM Loss')

axs[1, 0].plot(qlstm_attn_loss,label='Quantum DA-LSTM')
axs[1, 0].plot(lstm_attn_loss,label='Classical DA-LSTM')
axs[1, 0].legend()
axs[1, 0].set_title('Quantum DA-LSTM Vs Classical DA-LSTM Loss')

axs[1, 1].plot(stacked_qlstm_loss,label='Quantum stacked LSTM' )
axs[1, 1].plot(stacked_lstm_loss,label='Classical stacked LSTM')
axs[1, 1].legend()
axs[1, 1].set_title('Quantum stacked LSTM Vs Classical stacked LSTM Loss')

axs[1, 2].plot(stacked_qgru_loss,label='Quantum stacked GRU')
axs[1, 2].plot(stacked_gru_loss,label='Classical stacked GRU')
axs[1, 2].legend()
axs[1, 2].set_title('Quantum stacked GRU Vs Classical stacked GRU Loss')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2,3, figsize=(20, 8))

axs[0, 0].plot(qlstm_test, label='Quantum LSTM', color='red', alpha=0.7)
axs[0, 0].plot(lstm_test, label= 'Classical LSTM', alpha=0.4)
axs[0, 0].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[0, 0].legend()
axs[0, 0].set_title('Quantum LSTM Vs Classical LSTM testing')

axs[0, 1].plot(qgru_test, label='Quantum GRU', color='red', alpha=0.7)
axs[0, 1].plot(gru_test, label='Classical GRU', alpha=0.4)
axs[0, 1].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[0, 1].legend()
axs[0, 1].set_title('Quantum GRU Vs Classical GRU testing')

axs[0, 2].plot(qblstm_test, label='Quantum BiLSTM', color='red', alpha=0.7)
axs[0, 2].plot(blstm_test, label='Classical BiLSTM', alpha=0.4)
axs[0, 2].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[0, 2].legend()
axs[0, 2].set_title('Quantum BiLSTM Vs Classical BiLSTM testing')

axs[1, 0].plot(qlstm_attn_test,label='Quantum DA-LSTM', color='red', alpha=0.7)
axs[1, 0].plot(lstm_attn_test,label='Classical DA-LSTM', alpha=0.4)
axs[1, 0].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[1, 0].legend()
axs[1, 0].set_title('Quantum DA-LSTM Vs Classical DA-LSTM testing')

axs[1, 1].plot(stacked_qlstm_test,label='Quantum stacked LSTM' , color='red', alpha=0.7)
axs[1, 1].plot(stacked_lstm_test,label='Classical stacked LSTM', alpha=0.4)
axs[1, 1].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[1, 1].legend()
axs[1, 1].set_title('Quantum stacked LSTM Vs Classical stacked LSTM testing')

axs[1, 2].plot(stacked_qgru_test,label='Quantum stacked GRU', color='red', alpha=0.7)
axs[1, 2].plot(stacked_gru_test,label='Classical stacked GRU', alpha=0.4)
axs[1, 2].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[1, 2].legend()
axs[1, 2].set_title('Quantum stacked GRU Vs Classical stacked GRU testing')

plt.tight_layout()
plt.show()

# %%
plt.plot(arima_qlstm_loss, label='ARIMA QLSTM')
plt.plot(arima_lstm_loss, label='ARIMA LSTM')
plt.legend()
plt.title('Quantum ARIMA QLSTM Vs Classical ARIMA LSTM Loss')
plt.show()

# %%
plt.plot(arima_qlstm_test, label='ARIMA QLSTM')
plt.plot(arima_lstm_test, label='ARIMA LSTM')
plt.legend()
plt.title('Quantum ARIMA QLSTM Vs Classical ARIMA LSTM testing')
plt.show()

# %%
X = ['LSTM', 'BiLSTM', 'GRU', 'DA-LSTM','Stacked LSTM', 'Stacked GRU', 'ARIMA-LSTM']
rmse_q = [1.7084418035600935,1.0026308962033648,1.5661025363216956,0.3766637779848032,1.5143905137615254,1.687755889168282,1.2240565144748539]
rmse_c = [1.2818630170896148,0.7379342817734963,1.350441374151375,0.13590926773844886,1.290998485375683,1.594170564598244,0.8404795933062871]

X_axis = np.arange(len(X)) 
plt.figure(figsize=(20,8))  
plt.bar(X_axis - 0.2, rmse_q, 0.4, label = 'Quantum RMSE') 
plt.bar(X_axis + 0.2, rmse_c, 0.4, label = 'Classical RMSE') 

plt.xticks(X_axis, X) 
plt.title("RMSE of Quantum and Classical LSTM Variants") 
plt.legend() 
plt.show()

# %%
import pandas as pd
rmse_models_NY = pd.DataFrame({'Model_Name': X, 'Quanutum RMSE': rmse_q, 'Classical RMSE': rmse_c})
rmse_models_NY
# Out:
#      Model_Name  Quanutum RMSE  Classical RMSE
# 0          LSTM       1.708442        1.281863
# 1        BiLSTM       1.002631        0.737934
# 2           GRU       1.566103        1.350441
# 3       DA-LSTM       0.376664        0.135909
# 4  Stacked LSTM       1.514391        1.290998
# 5   Stacked GRU       1.687756        1.594171
# 6    ARIMA-LSTM       1.224057        0.840480
