# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
qlstm_loss = np.loadtxt('./SavedModels/Loss/qlstm.txt')
qgru_loss = np.loadtxt('./SavedModels/Loss/qgru.txt')
qlstm_attn_loss = np.loadtxt('./SavedModels/Loss/qlstm_attn.txt')
stacked_qlstm_loss = np.loadtxt('./SavedModels/Loss/stacked_qlstm.txt')
stacked_qgru_loss = np.loadtxt('./SavedModels/Loss/stacked_qgru.txt')
arima_qlstm_loss = np.loadtxt('./SavedModels/Loss/arima_qlstm.txt')
qblstm_loss = np.loadtxt('./SavedModels/Loss/qblstm.txt')

lstm_loss = np.loadtxt('./SavedModels/Loss/clstm.txt')
gru_loss = np.loadtxt('./SavedModels/Loss/cgru.txt')
lstm_attn_loss = np.loadtxt('./SavedModels/Loss/clstm_attn.txt')
stacked_lstm_loss = np.loadtxt('./SavedModels/Loss/stacked_clstm.txt')
stacked_gru_loss = np.loadtxt('./SavedModels/Loss/stacked_cgru.txt')
arima_lstm_loss = np.loadtxt('./SavedModels/Loss/arima_lstm.txt')
blstm_loss = np.loadtxt('./SavedModels/Loss/cblstm.txt')

# %%
y_train = np.loadtxt('./SavedModels/y_train_true.txt')
y_test = np.loadtxt('./SavedModels/y_test_true.txt')

# %%
qlstm_train = np.loadtxt('./SavedModels/Train/qlstm.txt')
qgru_train = np.loadtxt('./SavedModels/Train/qgru.txt')
qlstm_attn_train = np.loadtxt('./SavedModels/Train/qlstm_attn.txt')
stacked_qlstm_train = np.loadtxt('./SavedModels/Train/stacked_qlstm.txt')
stacked_qgru_train = np.loadtxt('./SavedModels/Train/stacked_qgru.txt')
arima_qlstm_train = np.loadtxt('./SavedModels/Train/arima_qlstm.txt')
qblstm_train = np.loadtxt('./SavedModels/Train/qblstm.txt')

lstm_train = np.loadtxt('./SavedModels/Train/clstm.txt')
gru_train = np.loadtxt('./SavedModels/Train/cgru.txt')
lstm_attn_train = np.loadtxt('./SavedModels/Train/clstm_attn.txt')
stacked_lstm_train = np.loadtxt('./SavedModels/Train/stacked_clstm.txt')
stacked_gru_train = np.loadtxt('./SavedModels/Train/stacked_cgru.txt')
arima_lstm_train= np.loadtxt('./SavedModels/Train/arima_lstm.txt')
blstm_train = np.loadtxt('./SavedModels/Train/cblstm.txt')

# %%
qlstm_test = np.loadtxt('./SavedModels/Test/qlstm.txt')
qgru_test = np.loadtxt('./SavedModels/Test/qgru.txt')
qlstm_attn_test= np.loadtxt('./SavedModels/Test/qlstm_attn.txt')
stacked_qlstm_test = np.loadtxt('./SavedModels/Test/stacked_qlstm.txt')
stacked_qgru_test = np.loadtxt('./SavedModels/Test/stacked_qgru.txt')
arima_qlstm_test = np.loadtxt('./SavedModels/Test/arima_qlstm.txt')
qblstm_test = np.loadtxt('./SavedModels/Test/qblstm.txt')

lstm_test = np.loadtxt('./SavedModels/Test/clstm.txt')
gru_test = np.loadtxt('./SavedModels/Test/cgru.txt')
lstm_attn_test = np.loadtxt('./SavedModels/Test/clstm_attn.txt')
stacked_lstm_test = np.loadtxt('./SavedModels/Test/stacked_clstm.txt')
stacked_gru_test = np.loadtxt('./SavedModels/Test/stacked_cgru.txt')
arima_lstm_test= np.loadtxt('./SavedModels/Test/arima_lstm.txt')
blstm_test = np.loadtxt('./SavedModels/Test/cblstm.txt')

# %%
fig, axs = plt.subplots(2,3, figsize=(20, 8))

axs[0, 0].plot(qlstm_loss, label='Quantum LSTM')
axs[0, 0].plot(lstm_loss, label= 'Classical LSTM')
axs[0, 0].legend()
axs[0, 0].set_title('Quantum LSTM Vs Classical LSTM Loss')

axs[0, 1].plot(qgru_loss, label='Quantum GRU')
axs[0, 1].plot(gru_loss, label='Classical GRU')
axs[0, 1].legend()
axs[0, 1].set_title('Quantum GRU Vs Classical GRU Loss')

axs[0, 2].plot(qblstm_loss, label='Quantum BiLSTM')
axs[0, 2].plot(blstm_loss, label='Classical BiLSTM')
axs[0, 2].legend()
axs[0, 2].set_title('Quantum BiLSTM Vs Classical BiLSTM Loss')

axs[1, 0].plot(qlstm_attn_loss,label='Quantum DA-LSTM')
axs[1, 0].plot(lstm_attn_loss,label='Classical DA-LSTM')
axs[1, 0].legend()
axs[1, 0].set_title('Quantum DA-LSTM Vs Classical DA-LSTM Loss')

axs[1, 1].plot(stacked_qlstm_loss,label='Quantum stacked LSTM' )
axs[1, 1].plot(stacked_lstm_loss,label='Classical stacked LSTM')
axs[1, 1].legend()
axs[1, 1].set_title('Quantum stacked LSTM Vs Classical stacked LSTM Loss')

axs[1, 2].plot(stacked_qgru_loss,label='Quantum stacked GRU')
axs[1, 2].plot(stacked_gru_loss,label='Classical stacked GRU')
axs[1, 2].legend()
axs[1, 2].set_title('Quantum stacked GRU Vs Classical stacked GRU Loss')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2,3, figsize=(20, 8))

axs[0, 0].plot(qlstm_test, label='Quantum LSTM', color='red', alpha=0.7)
axs[0, 0].plot(lstm_test, label= 'Classical LSTM', alpha=0.4)
axs[0, 0].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[0, 0].legend()
axs[0, 0].set_title('Quantum LSTM Vs Classical LSTM testing')

axs[0, 1].plot(qgru_test, label='Quantum GRU', color='red', alpha=0.7)
axs[0, 1].plot(gru_test, label='Classical GRU', alpha=0.4)
axs[0, 1].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[0, 1].legend()
axs[0, 1].set_title('Quantum GRU Vs Classical GRU testing')

axs[0, 2].plot(qblstm_test, label='Quantum BiLSTM', color='red', alpha=0.7)
axs[0, 2].plot(blstm_test, label='Classical BiLSTM', alpha=0.4)
axs[0, 2].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[0, 2].legend()
axs[0, 2].set_title('Quantum BiLSTM Vs Classical BiLSTM testing')

axs[1, 0].plot(qlstm_attn_test,label='Quantum DA-LSTM', color='red', alpha=0.7)
axs[1, 0].plot(lstm_attn_test,label='Classical DA-LSTM', alpha=0.4)
axs[1, 0].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[1, 0].legend()
axs[1, 0].set_title('Quantum DA-LSTM Vs Classical DA-LSTM testing')

axs[1, 1].plot(stacked_qlstm_test,label='Quantum stacked LSTM' , color='red', alpha=0.7)
axs[1, 1].plot(stacked_lstm_test,label='Classical stacked LSTM', alpha=0.4)
axs[1, 1].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[1, 1].legend()
axs[1, 1].set_title('Quantum stacked LSTM Vs Classical stacked LSTM testing')

axs[1, 2].plot(stacked_qgru_test,label='Quantum stacked GRU', color='red', alpha=0.7)
axs[1, 2].plot(stacked_gru_test,label='Classical stacked GRU', alpha=0.4)
axs[1, 2].plot(y_test, label= 'Actual Value', alpha=0.4)
axs[1, 2].legend()
axs[1, 2].set_title('Quantum stacked GRU Vs Classical stacked GRU testing')

plt.tight_layout()
plt.show()

# %%
plt.plot(arima_qlstm_loss, label='ARIMA QLSTM')
plt.plot(arima_lstm_loss, label='ARIMA LSTM')
plt.legend()
plt.title('Quantum ARIMA QLSTM Vs Classical ARIMA LSTM Loss')
plt.show()

# %%
plt.plot(arima_qlstm_test, label='ARIMA QLSTM')
plt.plot(arima_lstm_test, label='ARIMA LSTM')
plt.legend()
plt.title('Quantum ARIMA QLSTM Vs Classical ARIMA LSTM testing')
plt.show()

# %%
X = ['LSTM', 'BiLSTM', 'GRU', 'DA-LSTM','Stacked LSTM', 'Stacked GRU', 'ARIMA-LSTM']
rmse_q = [20.100118904404763,25.932686378814985,20.62787531646418,8.746741527123874,24.54570604900776,21.391885269573052,17.64466928828199]
rmse_c = [20.939787580193812,23.717426406604122,21.841767692325643,1.31321549936287,23.07959328580756,28.424751391438264,22.056887988984787]

X_axis = np.arange(len(X)) 
plt.figure(figsize=(20,8))  
plt.bar(X_axis - 0.2, rmse_q, 0.4, label = 'Quantum RMSE') 
plt.bar(X_axis + 0.2, rmse_c, 0.4, label = 'Classical RMSE') 

plt.xticks(X_axis, X) 
plt.title("RMSE of Quantum and Classical LSTM Variants") 
plt.legend() 
plt.show()
